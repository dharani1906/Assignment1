# %% [markdown]
# ### Read Datasets(csv,json,parquet)

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %% [markdown]
# ## CSV File

# %%
csv_path="C:\\Users\\dhara\\Downloads\\customers-10000.csv"

# %% [markdown]
# ### Read  dataset

# %%
df_csv1=pd.read_csv(csv_path)

# %%
df_csv1
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
csv_path2="C:\\Users\\dhara\\Downloads\\city.csv.csv"

# %%
csv_path3="C:\\Users\\dhara\\Downloads\\csv\\email.csv"

# %%
df_csv2=pd.read_csv(csv_path)

# %%
df_csv3=pd.read_csv(csv_path)

# %%
df_csv2
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
df_csv2
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
df_csv1.head()
# Out:
#    Index      Customer Id First Name  Last Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather   Callahan              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina    Ferrell  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# ...

# %%
df_csv2.tail()
# Out:
#       Index      Customer Id First Name   Last Name         Company  \
# 9995   9996  DD0caa06ebf217c     Meghan       Cline  Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena     Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key        Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey       Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery    Burns-Holden
#
#                 City                       Country                Phone 1  \
# 9995      Petersport                 Cote d'Ivoire   001-270-136-4738x419
# 9996      Briggsport                       Namibia   +1-531-494-7645x4844
# 9997  West Joyceport  United States Virgin Islands     520.109.2482x26052
# 9998  Camachochester                         Niger       001-465-242-9979
# 9999      Sparkstown                       Tunisia  +1-889-682-9490x65400
#
#                     Phone 2                                 Email  \
# ...

# %% [markdown]
# ### JSON File

# %%
import json

# %%
import os

# %%
import pandas as pd

# %%
json_path1="C:\\Users\\dhara\\Documents\\dharani\\500.json"

# %%
with open(json_path1,"r")as file:
    data1=json.load(file)

# %%
df_json1=pd.json_normalize(raw_data1)

# %%
df_json1
# Out:
#                                        id  firstName     lastName  \
# 0    11f39ca8-0ae3-4ed7-bda5-09401ae3ddd0    Bethany     Prohaska
# 1    7a2886cc-ccd1-4609-b9fd-72b7694a58e2     Cydney       Jacobi
# 2    fa1e2c1c-5760-4bd3-ac99-66772c0b5384       Raul  Stoltenberg
# 3    7b637405-afab-4ca4-8d59-f257d4e44f7b       Rita        Kling
# 4    7e944f03-a1c4-4eff-b167-b5aa20848282      Madge        Yundt
# ..                                    ...        ...          ...
# 495  3ac787c7-c12a-4cfc-b1c8-0280002b5b42     Carter         Will
# 496  062ebb1c-c508-45b6-a2d2-6b9a42b1b1ba  Johnathon       Little
# 497  5cff333b-73d2-4042-a122-fae410e94252     Millie      Bradtke
# 498  8b71efb5-e8e7-4703-957a-313706f44f37    Elliott  Greenfelder
# 499  2f4da3a5-e04d-4f84-8c4c-8d2f2e02514c    Natalia        Crist
#
#                             email                username  \
# 0              Bertha45@yahoo.com   Nicholaus_Schroeder12
# ...

# %%
df_json1.head()
# Out:
#                                      id firstName     lastName  \
# 0  11f39ca8-0ae3-4ed7-bda5-09401ae3ddd0   Bethany     Prohaska
# 1  7a2886cc-ccd1-4609-b9fd-72b7694a58e2    Cydney       Jacobi
# 2  fa1e2c1c-5760-4bd3-ac99-66772c0b5384      Raul  Stoltenberg
# 3  7b637405-afab-4ca4-8d59-f257d4e44f7b      Rita        Kling
# 4  7e944f03-a1c4-4eff-b167-b5aa20848282     Madge        Yundt
#
#                           email               username                  phone
# 0            Bertha45@yahoo.com  Nicholaus_Schroeder12     678.898.8618 x1599
# 1          Amanda91@hotmail.com                  Ned36    (571) 343-4863 x461
# 2  Tierra.Friesen18@hotmail.com       Leanne.Abshire13         1-993-432-4283
# 3        Morgan.Brown@yahoo.com            Matt.Hammes  1-925-583-9516 x91812
# 4      Shakira.Moen93@gmail.com         Isai_Abshire91    596-467-4510 x25659

# %%
df_json1.tail()
# Out:
#                                        id  firstName     lastName  \
# 495  3ac787c7-c12a-4cfc-b1c8-0280002b5b42     Carter         Will
# 496  062ebb1c-c508-45b6-a2d2-6b9a42b1b1ba  Johnathon       Little
# 497  5cff333b-73d2-4042-a122-fae410e94252     Millie      Bradtke
# 498  8b71efb5-e8e7-4703-957a-313706f44f37    Elliott  Greenfelder
# 499  2f4da3a5-e04d-4f84-8c4c-8d2f2e02514c    Natalia        Crist
#
#                       email                username                 phone
# 495   Madison70@hotmail.com  Leann_Miller-Murazik28    953-414-9709 x6253
# 496     Brendon76@yahoo.com               Margret16  (658) 842-1640 x0989
# 497  Jevon_Bode64@yahoo.com                Helena42   (510) 233-8223 x085
# 498      Haylee89@gmail.com      Hollie_Cummerata46    707.369.1521 x3828
# 499   Ryleigh58@hotmail.com         Keanu.Effertz27    937-324-0743 x9345

# %%
print("Total JSOM Records:",len(data1))
# Out:
# Total JSOM Records: 500

# %%
print("\nFlattend JSON columns:")
print(df_json1.columns)
# Out:
# Flattend JSON columns:
# Index(['id', 'firstName', 'lastName', 'email', 'username', 'phone'], dtype='str')

# %% [markdown]
# ### Parquet file

# %%
pip install pyarrow
# Out:
# ...
#   Using cached pyarrow-23.0.1-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# ...
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
# ...

# %%
import pandas as pd

# %%
parquet_path="C:\\Users\\dhara\\Documents\\dharani\\weather.parquet"

# %%
df_parquet=pd.read_parquet(parquet_path,engine="pyarrow")

# %%
df_parquet
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4      6.3          NW
# 1       14.0     26.9       3.6          4.4      9.7         ENE
# 2       13.7     23.4       3.6          5.8      3.3          NW
# 3       13.3     15.5      39.8          7.2      9.1          NW
# 4        7.6     16.1       2.8          5.6     10.6         SSE
# ..       ...      ...       ...          ...      ...         ...
# 361      9.0     30.7       0.0          7.6     12.1         NNW
# 362      7.1     28.4       0.0         11.6     12.7           N
# 363     12.5     19.9       0.0          8.4      5.3         ESE
# 364     12.5     26.9       0.0          5.0      7.1          NW
# 365     12.3     30.2       0.0          6.0     12.6          NW
#
#     WindGustSpeed WindDir9am WindDir3pm WindSpeed9am  ...  Humidity3pm  \
# 0              30         SW         NW            6  ...           29
# ...

# %%
print("\nSample Records:")
print(df_parquet.head())
# Out:
# Sample Records:
#    MinTemp  MaxTemp  Rainfall  Evaporation Sunshine WindGustDir WindGustSpeed  \
# 0      8.0     24.3       0.0          3.4      6.3          NW            30
# 1     14.0     26.9       3.6          4.4      9.7         ENE            39
# 2     13.7     23.4       3.6          5.8      3.3          NW            85
# 3     13.3     15.5      39.8          7.2      9.1          NW            54
# 4      7.6     16.1       2.8          5.6     10.6         SSE            50
#
#   WindDir9am WindDir3pm WindSpeed9am  ...  Humidity3pm  Pressure9am  \
# 0         SW         NW            6  ...           29       1019.7
# 1          E          W            4  ...           36       1012.4
# 2          N        NNE            6  ...           69       1009.5
# 3        WNW          W           30  ...           56       1005.5
# 4        SSE        ESE           20  ...           49       1018.3
#
# ...

# %%
print("\nSample Records:")
print(df_parquet.tail())
# Out:
# Sample Records:
#      MinTemp  MaxTemp  Rainfall  Evaporation Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6     12.1         NNW
# 362      7.1     28.4       0.0         11.6     12.7           N
# 363     12.5     19.9       0.0          8.4      5.3         ESE
# 364     12.5     26.9       0.0          5.0      7.1          NW
# 365     12.3     30.2       0.0          6.0     12.6          NW
#
#     WindGustSpeed WindDir9am WindDir3pm WindSpeed9am  ...  Humidity3pm  \
# 361            76        SSE         NW            7  ...           15
# 362            48        NNW        NNW            2  ...           22
# 363            43        ENE        ENE           11  ...           47
# 364            46        SSW        WNW            6  ...           39
# 365            78         NW        WNW           31  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
print("\nparquet Data Types:")
print(df_parquet.dtypes)
# Out:
# parquet Data Types:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine             str
# WindGustDir          str
# WindGustSpeed        str
# WindDir9am           str
# WindDir3pm           str
# WindSpeed9am         str
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday            str
# RISK_MM          float64
# RainTomorrow         str
# dtype: object
